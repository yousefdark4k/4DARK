# %% [markdown]
# <a href="https://colab.research.google.com/github/yousefdark4k/4DARK/blob/main/Topazer_With_DLSS5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **TO GET THE ACCESS TOKEN OR KEY USE [@xyethercolabid_bot](https://t.me/xyethercolabid_bot)**

# %% [markdown]
# .

# %% [markdown]
# <div style="display: flex; flex-direction: column; gap: 14px;">
#   <a href="https://t.me/xyethercolabs" target="_blank">
#     <img src="https://img.shields.io/badge/Telegram-@xyethercolabs-2CA5E0?style=for-the-badge&logo=telegram&logoColor=white" alt="Telegram" />
#   </a>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp
#   <a href="https://t.me/xyethercolabid_bot" target="_blank">
#     <img src="https://img.shields.io/badge/Telegram_Bot-@xyethercolabid__bot-2CA5E0?style=for-the-badge&logo=telegram&logoColor=white" alt="Telegram Bot" />
#   </a>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp
#   <a href="https://ko-fi.com/chisaxd" target="_blank">
#     <img src="https://img.shields.io/badge/Ko--fi-Support-FF5E5B?style=for-the-badge&logo=ko-fi&logoColor=white" alt="Ko-fi" />
#   </a>
# </div>

# %% [markdown]
# .

# %%
# -*- coding: utf-8 -*-
# @title Run Setup {display-mode: "form" }
Auth_Token = "xct4qc7g853hb7pFBfbppo0TeHTa3Say"  # @param {type:"string"}

import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "gdown"])
import gdown
file_id = "1C0EORXNUO7Y4QAkFQkLgOr8Ck6kjYV1H"
url = f"https://drive.google.com/uc?id={file_id}"
gdown.download(url, output="/content/config_utils.so", quiet=False)

import config_utils
token = Auth_Token.strip()
auth_fn = getattr(config_utils, "authenticate_booster_topazer", None) or getattr(config_utils, "authenticate_telegram", None) or getattr(config_utils, "setup_environment", None)
if auth_fn:
    auth_fn(token)
else:
    print("❌ Error: Verification entry point missing in binary.")

# %%
# @title Video Processing { display-mode: "form" }

input_path = ""  # @param {type:"string"}

model = "RheaXL"  # @param ["RheaXL", "Rhea", "Proteus", "Iris", "Image", "XyetherIRL", "Off"]
scale = "2x"  # @param ["1x", "2x", "4x"]

speed_boost = False  # @param {type:"boolean"}
dlss5 = True  # @param {type:"boolean"}
nr_style = "0 Default"  # @param ["0 Default", "1 Natural", "2 Cinematic (experimental)"]
nr_preset = "0 Default"  # @param ["0 Default", "1 Preset #1", "2 Preset #2", "3 Preset #3"]

encoder_choice = "hevc_nvenc (H.265 8-bit)"  # @param ["hevc_nvenc (H.265 10-bit)", "hevc_nvenc (H.265 8-bit)", "h264_nvenc (H.264 8-bit)", "h264_nvenc (H.264 10-bit)"]
# @title Model Parameters
revert_compression = 0  # @param {type:"slider", min:0, max:100, step:1}
recover_details = 0  # @param {type:"slider", min:0, max:100, step:1}
sharpen = 0  # @param {type:"slider", min:0, max:100, step:1}
reduce_noise = 0  # @param {type:"slider", min:0, max:100, step:1}
dehalo = 0  # @param {type:"slider", min:0, max:100, step:1}
anti_alias_deblur = 0  # @param {type:"slider", min:-100, max:100, step:1}

auto_download = True  # @param {type:"boolean"}

import config_utils

config_utils.run_processing(
    input_path=input_path,
    model=model,
    scale=scale,
    speed_boost=speed_boost,
    dlss5=dlss5,
    nr_style=nr_style,
    nr_preset=nr_preset,
    encoder_choice=encoder_choice,
    revert_compression=revert_compression,
    recover_details=recover_details,
    sharpen=sharpen,
    reduce_noise=reduce_noise,
    dehalo=dehalo,
    anti_alias_deblur=anti_alias_deblur,
    auto_download=auto_download
)

# %% [markdown]
# .

# %% [markdown]
# <div style="display: flex; flex-direction: column; gap: 14px;">
#   <a href="https://t.me/xyethercolabs" target="_blank">
#     <img src="https://img.shields.io/badge/Telegram-@xyethercolabs-2CA5E0?style=for-the-badge&logo=telegram&logoColor=white" alt="Telegram" />
#   </a>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp
#   <a href="https://t.me/xyethercolabid_bot" target="_blank">
#     <img src="https://img.shields.io/badge/Telegram_Bot-@xyethercolabid__bot-2CA5E0?style=for-the-badge&logo=telegram&logoColor=white" alt="Telegram Bot" />
#   </a>&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp
#   <a href="https://ko-fi.com/chisaxd" target="_blank">
#     <img src="https://img.shields.io/badge/Ko--fi-Support-FF5E5B?style=for-the-badge&logo=ko-fi&logoColor=white" alt="Ko-fi" />
#   </a>
# </div>

# %% [markdown]
# .

# %% [markdown]
# # **NOTE:-**
# 1. All the credits goes to xyether and his team. We won't allow anyone to modify or get models freely.
#
# 2. For the promotions contact us in Telegram.
#
# 3. Support us through boosting our Telegram Chanel or chisa's ko-fi profile [Link](https://ko-fi.com/chisaxd).
